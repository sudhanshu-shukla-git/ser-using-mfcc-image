# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_source = pd.read_csv("../file_source.csv")

# %%
file_source.Source.value_counts()
# Out:
# IEMOCAP    7532
# RAVDESS    1440
# EMODB       535
# SAVEE       480
# Name: Source, dtype: int64

# %%
ravdess_df = file_source[file_source.Source=="RAVDESS"]

# %%
pd.Series(ravdess_df.Emotions.unique()).apply(lambda x : x.title())
# Out:
# 0        Fear
# 1       Angry
# 2     Neutral
# 3        Calm
# 4     Disgust
# 5       Happy
# 6    Surprise
# 7         Sad
# dtype: object

# %%
plt.figure(figsize=(10,3))
# plt.title('Count of Emotions', size=16)

ax = sns.countplot(ravdess_df, x="Emotions")
ax.bar_label(ax.containers[0])


plt.ylabel('Count', size=12)
plt.xlabel('Emotions', size=12)
sns.despine(top=True, right=True, left=False, bottom=False)
plt.show()

# %%
ravdess_df["Audio Length"].describe().reset_index()
# Out:
#    index  Audio Length
# 0  count   1440.000000
# 1   mean      3.700665
# 2    std      0.336676
# 3    min      2.936271
# 4    25%      3.470146
# 5    50%      3.670333
# 6    75%      3.870542
# 7    max      5.271937

# %%
plt.figure(figsize=(10,3))
# plt.title('Audio Length', size=16)
ravdess_df["Audio Length"].plot(kind="hist")
# plt.ylabel('Count', size=12)
plt.xlabel('Audio Length (seconds)', size=12)
# sns.despine(top=True, right=True, left=False, bottom=False)
plt.show()

# %%
ravdess_df["Trimmed Audio Length"].describe().reset_index()
# Out:
#    index  Trimmed Audio Length
# 0  count           1440.000000
# 1   mean              2.228469
# 2    std              1.324275
# 3    min              0.003000
# 4    25%              1.210000
# 5    50%              1.804000
# 6    75%              3.536875
# 7    max              4.838167

# %%
plt.figure(figsize=(10,3))
# plt.title('Audio Length', size=16)
ravdess_df["Trimmed Audio Length"].plot(kind="hist")
# plt.ylabel('Count', size=12)
plt.xlabel('Audio Length (seconds)', size=12)
# sns.despine(top=True, right=True, left=False, bottom=False)
plt.show()

# %%
plt.figure(figsize=(10,3))
# plt.title('Audio Length', size=16)

sns.boxplot(ravdess_df, x="Trimmed Audio Length")
# plt.ylabel('Count', size=12)
# plt.xlabel('Emotions', size=12)
# sns.despine(top=True, right=True, left=False, bottom=False)
plt.show()
