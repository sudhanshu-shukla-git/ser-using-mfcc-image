# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_source = pd.read_csv("../file_source.csv")

# %%
file_source.Source.value_counts()
# Out:
# IEMOCAP    7532
# RAVDESS    1440
# EMODB       535
# SAVEE       480
# Name: Source, dtype: int64

# %%
Iemocap_df = file_source[file_source.Source=="IEMOCAP"]

# %%
pd.Series(Iemocap_df.Emotions.unique()).apply(lambda x : x.title()).to
# Out:
# 0        Neutral
# 1    Frustration
# 2       Surprise
# 3          Angry
# 4          Happy
# 5            Sad
# 6     Excitement
# 7          Other
# 8           Fear
# 9        Disgust
# dtype: object

# %%
plt.figure(figsize=(10,3))
# plt.title('Count of Emotions', size=16)

ax = sns.countplot(Iemocap_df, x="Emotions")
ax.bar_label(ax.containers[0])


plt.ylabel('Count', size=12)
plt.xlabel('Emotions', size=12)
sns.despine(top=True, right=True, left=False, bottom=False)
plt.show()

# %%
Iemocap_df["Audio Length"].describe().reset_index()
# Out:
#    index  Audio Length
# 0  count   7532.000000
# 1   mean      4.558042
# 2    std      3.157435
# 3    min      0.584937
# 4    25%      2.341172
# 5    50%      3.610000
# 6    75%      5.850000
# 7    max     34.138750

# %%
plt.figure(figsize=(10,3))
# plt.title('Audio Length', size=16)
Iemocap_df["Audio Length"].plot(kind="hist")
# plt.ylabel('Count', size=12)
plt.xlabel('Audio Length (seconds)', size=12)
# sns.despine(top=True, right=True, left=False, bottom=False)
plt.show()

# %%
Iemocap_df["Trimmed Audio Length"].describe().reset_index()
# Out:
#    index  Trimmed Audio Length
# 0  count           7532.000000
# 1   mean              3.118582
# 2    std              2.959585
# 3    min              0.003000
# 4    25%              1.050000
# 5    50%              2.325000
# 6    75%              4.271375
# 7    max             32.999000

# %%
plt.figure(figsize=(10,3))
# plt.title('Audio Length', size=16)
Iemocap_df["Trimmed Audio Length"].plot(kind="hist")
# plt.ylabel('Count', size=12)
plt.xlabel('Audio Length (seconds)', size=12)
# sns.despine(top=True, right=True, left=False, bottom=False)
plt.show()

# %%
plt.figure(figsize=(10,3))
# plt.title('Audio Length', size=16)

sns.boxplot(Iemocap_df, x="Trimmed Audio Length")
# plt.ylabel('Count', size=12)
# plt.xlabel('Emotions', size=12)
# sns.despine(top=True, right=True, left=False, bottom=False)
plt.show()
