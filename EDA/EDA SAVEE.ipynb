# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_source = pd.read_csv("../file_source.csv")

# %%
file_source.Source.value_counts()
# Out:
# IEMOCAP    7532
# RAVDESS    1440
# EMODB       535
# SAVEE       480
# Name: Source, dtype: int64

# %%
savee_df = file_source[file_source.Source=="SAVEE"]

# %%
pd.Series(savee_df.Emotions.unique()).apply(lambda x : x.title())
# Out:
# 0       Happy
# 1     Neutral
# 2         Sad
# 3    Surprise
# 4       Angry
# 5        Fear
# 6     Disgust
# dtype: object

# %%
plt.figure(figsize=(10,3))
# plt.title('Count of Emotions', size=16)

ax = sns.countplot(savee_df, x="Emotions")
ax.bar_label(ax.containers[0])


plt.ylabel('Count', size=12)
plt.xlabel('Emotions', size=12)
sns.despine(top=True, right=True, left=False, bottom=False)
plt.show()

# %%
savee_df["Audio Length"].describe().reset_index()
# Out:
#    index  Audio Length
# 0  count    480.000000
# 1   mean      3.839474
# 2    std      1.078021
# 3    min      1.630907
# 4    25%      3.076525
# 5    50%      3.672971
# 6    75%      4.518486
# 7    max      7.138730

# %%
plt.figure(figsize=(10,3))
# plt.title('Audio Length', size=16)
savee_df["Audio Length"].plot(kind="hist")
# plt.ylabel('Count', size=12)
plt.xlabel('Audio Length (seconds)', size=12)
# sns.despine(top=True, right=True, left=False, bottom=False)
plt.show()

# %%
savee_df["Trimmed Audio Length"].describe().reset_index()
# Out:
#    index  Trimmed Audio Length
# 0  count            480.000000
# 1   mean              3.168239
# 2    std              1.481899
# 3    min              0.006984
# 4    25%              2.250992
# 5    50%              3.295941
# 6    75%              4.098231
# 7    max              7.138980

# %%
plt.figure(figsize=(10,3))
# plt.title('Audio Length', size=16)
savee_df["Trimmed Audio Length"].plot(kind="hist")
# plt.ylabel('Count', size=12)
plt.xlabel('Audio Length (seconds)', size=12)
# sns.despine(top=True, right=True, left=False, bottom=False)
plt.show()

# %%
plt.figure(figsize=(10,3))
# plt.title('Audio Length', size=16)

sns.boxplot(savee_df, x="Trimmed Audio Length")
# plt.ylabel('Count', size=12)
# plt.xlabel('Emotions', size=12)
# sns.despine(top=True, right=True, left=False, bottom=False)
plt.show()
